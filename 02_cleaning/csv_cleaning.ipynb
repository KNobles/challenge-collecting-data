# %%
import pandas as pd

# %%
df = pd.read_csv("Property_structured_data.csv")

# %%
df
# Out:
#        Unnamed: 0        id       locality type_of_property  \
# 0               0  10148922      Bruxelles        APARTMENT
# 1               1  10147556      Havelange        APARTMENT
# 2               2   9881253  Brussels City  APARTMENT_GROUP
# 3               3  10147547  SINT-ANTONIUS  APARTMENT_GROUP
# 4               4  10148143     Anderlecht        APARTMENT
# ...           ...       ...            ...              ...
# 17813       17813   9889346     Saint-Mard            HOUSE
# 17814       17814  10073906        Antwerp            HOUSE
# 17815       17815   9938208          Liège            HOUSE
# 17816       17816   9880528         Hannut            HOUSE
# 17817       17817   9998063         Oupeye            HOUSE
#
#       subtype_of_property      type_of_sale   price number_of_bedrooms  \
# 0               APARTMENT  residential_sale  275000                  3
# 1               PENTHOUSE  residential_sale   79000                  2
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# id                           0
# locality                     0
# type_of_property             0
# subtype_of_property          0
# type_of_sale                 0
# price                        0
# number_of_bedrooms           0
# surface                      0
# fully_equipped_kitchen       0
# furnished                    0
# open_fire                    0
# terrace                      0
# terrace_surface              0
# garden                       0
# garden_surface               0
# land_surface              3496
# number_of_facades         3831
# swimming_pool                0
# state_of_the_building     2589
# dtype: int64

# %%
df = df.fillna("None")

# %%
df
# Out:
#        Unnamed: 0        id       locality type_of_property  \
# 0               0  10148922      Bruxelles        APARTMENT
# 1               1  10147556      Havelange        APARTMENT
# 2               2   9881253  Brussels City  APARTMENT_GROUP
# 3               3  10147547  SINT-ANTONIUS  APARTMENT_GROUP
# 4               4  10148143     Anderlecht        APARTMENT
# ...           ...       ...            ...              ...
# 17813       17813   9889346     Saint-Mard            HOUSE
# 17814       17814  10073906        Antwerp            HOUSE
# 17815       17815   9938208          Liège            HOUSE
# 17816       17816   9880528         Hannut            HOUSE
# 17817       17817   9998063         Oupeye            HOUSE
#
#       subtype_of_property      type_of_sale   price number_of_bedrooms  \
# 0               APARTMENT  residential_sale  275000                  3
# 1               PENTHOUSE  residential_sale   79000                  2
# ...

# %%
pd.DataFrame.to_csv(df)
# Out:
# Unnamed: 0                   0
# id                           0
# locality                     0
# type_of_property             0
# subtype_of_property          0
# type_of_sale                 0
# price                        0
# number_of_bedrooms           0
# surface                      0
# fully_equipped_kitchen       0
# furnished                    0
# open_fire                    0
# terrace                      0
# terrace_surface              0
# garden                       0
# garden_surface               0
# land_surface              2695
# number_of_facades         2934
# swimming_pool                0
# state_of_the_building        0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0        id       locality type_of_property  \
# 0               0  10148922      Bruxelles        APARTMENT
# 1               1  10147556      Havelange        APARTMENT
# 2               2   9881253  Brussels City  APARTMENT_GROUP
# 3               3  10147547  SINT-ANTONIUS  APARTMENT_GROUP
# 4               4  10148143     Anderlecht        APARTMENT
# ...           ...       ...            ...              ...
# 17812       17812  10049136       Kapellen            HOUSE
# 17813       17813   9889346     Saint-Mard            HOUSE
# 17814       17814  10073906        Antwerp            HOUSE
# 17816       17816   9880528         Hannut            HOUSE
# 17817       17817   9998063         Oupeye            HOUSE
#
#       subtype_of_property      type_of_sale   price number_of_bedrooms  \
# 0               APARTMENT  residential_sale  275000                  3
# 1               PENTHOUSE  residential_sale   79000                  2
# ...

# %%
newdf = df.drop(df[df.price == "None"].index)
newdf
pd.DataFrame.to_csv(newdf,"test.csv", index=False)

# %%
newdf['price'] = newdf['price'].astype(str).astype(int)
print(newdf.dtypes)
# Out:
# Unnamed: 0                 int64
# id                         int64
# locality                  object
# type_of_property          object
# subtype_of_property       object
# type_of_sale              object
# price                      int64
# number_of_bedrooms        object
# surface                   object
# fully_equipped_kitchen    object
# furnished                  int64
# open_fire                  int64
# terrace                    int64
# terrace_surface           object
# garden                     int64
# garden_surface            object
# land_surface              object
# number_of_facades         object
# swimming_pool              int64
# state_of_the_building     object
# dtype: object

# %%
newdf['garden_surface'] = newdf.garden_surface.apply(pd.to_numeric, errors='ignore')
print(newdf['garden_surface'])
# Out:
# 0        None
# 1        None
# 4        None
# 5        None
# 6        None
#          ...
# 17813    None
# 17814    None
# 17815    None
# 17816    None
# 17817    None
# Name: garden_surface, Length: 16416, dtype: object

# %%
df.dtypes
# Out:
# post_code              int64
# type_of_property      object
# subtype               object
# price                float64
# construction_year     object
# state                 object
# type_of_sale          object
# bedrooms_count       float64
# habitable_surface    float64
# kitchen_type          object
# furnished               bool
# fireplace               bool
# has_terrace           object
# terrace_area          object
# has_garden            object
# garden_area           object
# land_area             object
# num_facade            object
# swimmingpool            bool
# dtype: object

# %%
import numpy

t = pd.DataFrame({'iteg': [1,2,3, numpy.nan], 'row': ["blabla","blabla","b","bl"]})
print(t.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 t = pd.DataFrame({'iteg': [1,2,3], 'row': ["blabla","blabla","b","bl"]})
#       2 print(t.dtypes)
#
# File ~/Documents/becode_projects/challenge-collecting-data/env/lib/python3.10/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# ...

# %%
df.to_csv('cleaned_dataset_properties.csv',index=False)
